# %% [markdown]
# # Quick details and look into the data #

# %%
import pandas as pd

# %% [markdown]
# Read in data

# %%
CNS_df = pd.read_excel("CNS_Majors_Data.xlsx")
Reg_df = pd.read_excel("20250919_Registrars_Data.xlsx")

# %% [markdown]
# Shape of our current datasets

# %%
CNS_df.shape, Reg_df.shape
# Out:
# ((4393, 15), (20101, 49))

# %% [markdown]
# Columns of our datasets

# %%
CNS_df.columns
# Out:
# Index(['Eff End Term', 'Award Type', 'Major', 'Plan Title', 'Term', 'Year',
#        'Course', 'Fifth Year', 'Description', 'Major Title', 'Eff Start Term',
#        'Tracking Major Title', 'Credits', 'Credits Max', 'Credits Min'],
#       dtype='object')

# %%
Reg_df.columns
# Out:
# Index(['CRSE_ID', 'CRSE_OFFER_NBR', 'CRSE_EFFDT', 'SUBJECT', 'CRSE_CODE',
#        'COURSE_TITLE_LONG', 'ACAD_ORG_MAU_DESCRFORMAL',
#        'ACAD_ORG_U1_DESCRFORMAL', 'RQRMNT_GROUP', 'EFFDT', 'DESCR254A',
#        'RQRMNT_USEAGE', 'RQRMNT_LIST_SEQ', 'RQ_CONNECT_TYPE', 'MIN_CRSES_REQD',
#        'MIN_UNITS_REQD', 'GRADE_POINTS_MIN', 'GPA_REQUIRED', 'RQ_LINE_KEY_NBR',
#        'RQ_GRP_LINE_NBR', 'RQ_GRP_LINE_TYPE', 'REQUIREMENT', 'REQUISITE_TYPE',
#        'SSR_DESCR80', 'RQDET_CRSE_ID', 'RQDET_CRSE', 'RQ_CONNECT',
#        'PARENTHESIS', 'MIN_CRSES_REQD.1', 'MIN_UNITS_REQD.1', 'CONDITION_CODE',
#        'CONDITION_OPERATOR', 'CONDITION_DATA', 'DESCR', 'RQRMNT_USEAGE.1',
#        'RQRMNT_LIST_SEQ.1', 'RQ_CONNECT_TYPE.1', 'MIN_CRSES_REQD.2',
#        'MIN_UNITS_REQD.2', 'GRADE_POINTS_MIN.1', 'GPA_REQUIRED.1',
#        'RQ_LINE_KEY_NBR.1', 'RQ_LINE_DET_SEQ', 'RQ_LINE_DET_TYPE',
#        'COURSE_LIST', 'CONDITION_CODE.1', 'CONDITION_OPERATOR.1',
# ...

# %% [markdown]
# Slight look into the content

# %%
CNS_df.head()
# Out:
#    Eff End Term Award Type  Major                      Plan Title Term  \
# 0          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 1          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 2          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 3          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 4          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
#
#        Year         Course Fifth Year        Description  \
# 0  Freshman        MTH 103         No  Actuarial Science
# 1  Freshman  ISS 200-Level         No  Actuarial Science
# 2  Freshman        PSL 250         No  Actuarial Science
# 3  Freshman        WRA 1XX         No  Actuarial Science
# 4    Junior         FI 311         No  Actuarial Science
#
#              Major Title Eff Start Term Tracking Major Title  Credits  \
# 0  Actuarial Science, BS           FS17                  NaN      120
# ...

# %%
Reg_df.head()
# Out:
#    CRSE_ID  CRSE_OFFER_NBR CRSE_EFFDT SUBJECT CRSE_CODE  \
# 0   100090               1 2023-05-06     ACC       201
# 1   100090               1 2023-05-06     ACC       201
# 2   100090               1 2023-05-06     ACC       201
# 3   100090               1 2023-05-06     ACC       201
# 4   100090               1 2023-05-06     ACC       201
#
#                     COURSE_TITLE_LONG       ACAD_ORG_MAU_DESCRFORMAL  \
# 0  Principles of Financial Accounting  Eli Broad College of Business
# 1  Principles of Financial Accounting  Eli Broad College of Business
# 2  Principles of Financial Accounting  Eli Broad College of Business
# 3  Principles of Financial Accounting  Eli Broad College of Business
# 4  Principles of Financial Accounting  Eli Broad College of Business
#
#               ACAD_ORG_U1_DESCRFORMAL  RQRMNT_GROUP      EFFDT  ...  \
# 0  Accounting and Information Systems        600038 2021-08-01  ...
# 1  Accounting and Information Systems        600038 2021-08-01  ...
# ...

# %%
# number of unique courses in this dataset
len(Reg_df['COURSE_TITLE_LONG'].unique())
# Out:
# 5625

# %%
# the unique plans in this dataset
CNS_df['Plan Title'].unique()
# Out:
# array(['Actuarial Science BS (MTH 103)', 'Actuarial Science BS (MTH 116)',
#        'Actuarial Science BS (MTH 132)',
#        'Advanced Mathematics BA from Calculus II',
#        'Advanced Mathematics BA from Linear Algebra',
#        'Advanced Mathematics BS from Calculus II',
#        'Advanced Mathematics BS from Linear Algebra', 'Astrophysics',
#        'Biochemistry and Molecular Biology (MTH 103)',
#        'Biochemistry and Molecular Biology (MTH 116)',
#        'Biochemistry and Molecular Biology (MTH 132)',
#        'Biochemistry and Molecular Biology/Biotechnology (MTH 103)',
#        'Biochemistry and Molecular Biology/Biotechnology (MTH 116)',
#        'Biochemistry and Molecular Biology/Biotechnology (MTH 132)',
#        'Biological Science - Interdepartmental (MTH 103)',
#        'Biological Science - Interdepartmental (MTH 116)',
#        'Biological Science - Interdepartmental (MTH 124)',
#        'Biological Science - Interdepartmental (MTH 132)',
# ...

# %%
# number of unique plans
len(CNS_df['Plan Title'].unique())
# Out:
# 103

# %%
# number of unique courses
len(CNS_df['Course'].unique())
# Out:
# 308

# %% [markdown]
# Quick look into more info on the data

# %%
CNS_df.describe(include="object")
# Out:
#        Award Type            Plan Title  Term       Year     Course  \
# count        4393                  4285  4393       4393       4393
# unique          2                   102     3          4        308
# top            BS  Zoology BS (MTH 116)    FS  Sophomore  Electives
# freq         3767                   150  2186       1175        650
#
#        Fifth Year Description  Major Title Eff Start Term  \
# count        4393        4393         4393           4393
# unique          2          27           34              8
# top            No     Zoology  Zoology, BS           FS10
# freq         4355         828          702           3088
#
#             Tracking Major Title
# count                        702
# unique                         7
# top     Zoo and Aquarium Science
# freq                         154

# %%
Reg_df.describe(include="object")
# Out:
#        SUBJECT  CRSE_CODE  COURSE_TITLE_LONG     ACAD_ORG_MAU_DESCRFORMAL  \
# count    20101      20101              20101                        20101
# unique     193       1442               5625                           18
# top        MUS        493  Independent Study  College of Arts and Letters
# freq       639        257                202                         3520
#
#        ACAD_ORG_U1_DESCRFORMAL  \
# count                    20101
# unique                     122
# top                    English
# freq                       734
#
#                                                 DESCR254A RQRMNT_USEAGE  \
# count                                               20097         20097
# unique                                               4499             1
# top     Prerequisite: (IAH 201 or IAH 202 or IAH 203 o...           ENR
# freq                                                  255         20097
#
# ...
