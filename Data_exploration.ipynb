# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("CNS_Majors_Data.xlsx")

# %%
df.shape
# Out:
# (4393, 15)

# %%
df.columns
# Out:
# Index(['Eff End Term', 'Award Type', 'Major', 'Plan Title', 'Term', 'Year',
#        'Course', 'Fifth Year', 'Description', 'Major Title', 'Eff Start Term',
#        'Tracking Major Title', 'Credits', 'Credits Max', 'Credits Min'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Eff End Term Award Type  Major                      Plan Title Term  \
# 0          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 1          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 2          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 3          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 4          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 5          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 6          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 7          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 8          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
# 9          9999         BS   7105  Actuarial Science BS (MTH 103)   FS
#
#        Year             Course Fifth Year        Description  \
# 0  Freshman            MTH 103         No  Actuarial Science
# 1  Freshman      ISS 200-Level         No  Actuarial Science
# ...

# %%
df['Plan Title'].unique()
# Out:
# array(['Actuarial Science BS (MTH 103)', 'Actuarial Science BS (MTH 116)',
#        'Actuarial Science BS (MTH 132)',
#        'Advanced Mathematics BA from Calculus II',
#        'Advanced Mathematics BA from Linear Algebra',
#        'Advanced Mathematics BS from Calculus II',
#        'Advanced Mathematics BS from Linear Algebra', 'Astrophysics',
#        'Biochemistry and Molecular Biology (MTH 103)',
#        'Biochemistry and Molecular Biology (MTH 116)',
#        'Biochemistry and Molecular Biology (MTH 132)',
#        'Biochemistry and Molecular Biology/Biotechnology (MTH 103)',
#        'Biochemistry and Molecular Biology/Biotechnology (MTH 116)',
#        'Biochemistry and Molecular Biology/Biotechnology (MTH 132)',
#        'Biological Science - Interdepartmental (MTH 103)',
#        'Biological Science - Interdepartmental (MTH 116)',
#        'Biological Science - Interdepartmental (MTH 124)',
#        'Biological Science - Interdepartmental (MTH 132)',
# ...

# %%
len(df['Plan Title'].unique())
# Out:
# 103

# %%
df['Year'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Year'>

# %%
len(df['Course'].unique())
# Out:
# 308

# %%
df.describe(include="object")
# Out:
#        Award Type            Plan Title  Term       Year     Course  \
# count        4393                  4285  4393       4393       4393
# unique          2                   102     3          4        308
# top            BS  Zoology BS (MTH 116)    FS  Sophomore  Electives
# freq         3767                   150  2186       1175        650
#
#        Fifth Year Description  Major Title Eff Start Term  \
# count        4393        4393         4393           4393
# unique          2          27           34              8
# top            No     Zoology  Zoology, BS           FS10
# freq         4355         828          702           3088
#
#             Tracking Major Title
# count                        702
# unique                         7
# top     Zoo and Aquarium Science
# freq                         154
